# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Полина, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента: </b>Согласна, ниже я добавила свою версию описания проекта</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# # Исследование пользователей сервиса аренды самокатов GoFast
#
# В нашем распоряжении данные о некоторых пользователях из нескольких городов, а также об их поездках и подписках.
#
# Нам доступны личные данные клиентов, такие как имя, возраст и город проживания. Также доступны данные о дистанции и продолжительности их поездкок и типе подписок. Кроме того, у нас есть данные о стоимости всех видов подписок. Необходимо проанализировать данные и проверить гипотезы, тем самым помочь бизнесу вырасти.
#
# **Цель исследования:**
#
# Оценить поведение пользователей с подпиской и без неё, чтобы определить их ценность для сервиса.
#
# **Ход исследования**
#
# Данные мы получили из файлов:
# - /datasets/users_go.csv
# - /datasets/rides_go.csv
# - /datasets/subscriptions_go.csv
#
# О качестве данных ничего не известно. Поэтому перед тем, как приступить к целям исследования, понадобится обзор и предобработка данных.
#
# Я проверю данные на ошибки и оценю их влияние на исследование. Затем, на этапе предобработки я поищу возможность исправить все ошибки данных, которые не приведут к искажению конечного результата. Далее, создам необходимые столбцы, и приступлю к проведению исследовательского анализа и проверки гипотез.
#
# Таким образом, моё исследование пройдёт в семь этапов:
#
# - Обзор/загрузка данных.
# - Предобработка данных.
# - Исследовательский анализ данных
# - Объединение данных
# - Подсчёт выручки
# - Проверка гипотез
# - Написание общего вывода.

# %% [markdown]
# ###  Загрузка данных

# %% [markdown]
# #### Прочтем CSV файлы

# %%
# импортируем библиотеку pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо. Модули выгружены

# %%
# прочитаем csv-файлы и добавим их в соответсвующие датафреймы
users = pd.read_csv('/datasets/users_go.csv', sep=',')
rides = pd.read_csv('/datasets/rides_go.csv', sep=',')
subscriptions = pd.read_csv('/datasets/subscriptions_go.csv', sep=',')

# %% [markdown]
# #### Изучим датасеты

# %%
#посмотрим на таблицу users
display(users.head())
users.info()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %%
#посмотрим на таблицу rides
display(rides.head())
rides.info()
# Out:
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %%
#посмотрим на таблицу subscriptions
display(subscriptions.head())
subscriptions.info()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# В рамках первичного анализа были загружены три таблицы: пользователи, поездки и подписки. Данные содержат информацию о личных характеристиках пользователей, параметрах поездок и типах подписок. Пропущенные значения отсутствуют, что позволяет сразу переходить к дальнейшему анализу.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Приведем столбец date к типу даты pandas.

# %%
rides['date'] = pd.to_datetime(rides['date'], format='%Y-%m-%d')

# %% [markdown]
# #### Создадим новый столбец с номером месяца на основе столбца date

# %%
rides['date_month'] = pd.DatetimeIndex(rides['date']).month

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить за какой период у нас данные. Проверить столбец длительности на предмет наличия аномалий. Например, если у нас разные года то январь 2021 и январь 2022 будут под одной цифрой (1).
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Учту в будущих проектах</div>

# %% [markdown]
# #### Проверим наличие дубликатов в датафреймах. (наличие пропусков мы уже проверили)

# %%
#Проверим данные на полные дубликаты строк
display(users.duplicated().sum())
display(rides.duplicated().sum())
display(subscriptions.duplicated().sum())
# Out:
# 31
# 0
# 0

# %%
#удалим дубликаты из таблицы users 
users = users.drop_duplicates()
#обновим индекс
users = users.reset_index()

# %%
#Посмотрим на уникальные значения в колонке city
users['city'].unique()
# Out:
# array(['Тюмень', 'Омск', 'Москва', 'Ростов-на-Дону', 'Краснодар',
#        'Пятигорск', 'Екатеринбург', 'Сочи'], dtype=object)

# %% [markdown]
# Неявных дубликатов не найдено

# %% [markdown]
# В рамках предобработки данных столбец date был преобразован в формат даты-времени, а также добавлен новый столбец с номером месяца. В таблице пользователей было обнаружен и удален 31 явный дубликат.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Частота встречаемости городов

# %%
#построим сводную таблицу и гистограмму
users.pivot_table(index='city', values='subscription_type', aggfunc='count').plot(
    kind='bar',legend=False, ylabel='frequency',title = 'Частота встречаемости городов'
)
# Out:
# <AxesSubplot:title={'center':'Частота встречаемости городов'}, xlabel='city', ylabel='frequency'>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В целом график построен корректно. Но хорошо бы его отсортировать и повернуть на 90 градусов

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента: </b>Согласна, ниже я добавила новую версию</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный и наглядный график 👍
#
# Здорово, когда он подписан. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %%
users['city'].value_counts(ascending= True).plot(
    kind= 'barh',
    figsize= (15,5),
    title= 'График частоты встречаемости городов',

)
# Out:
# <AxesSubplot:title={'center':'График частоты встречаемости городов'}>

# %% [markdown]
# Наибольшее количество пользователей представлено из города Пятигорск. В целом, распределение по городам достаточно равномерное, без выраженных аномалий.

# %% [markdown]
# #### Cоотношение пользователей с подпиской и без подписки

# %%
#построим сводную таблицу и гистограмму
users.pivot_table(index='subscription_type', values='user_id', aggfunc='count').plot(
    kind='bar',legend=False, ylabel='frequency',title = 'Cоотношение пользователей с подпиской и без подписки'
)

# %% [markdown]
# Количество пользователей без подписки немного привышает количество пользователей с подпиской - 54% и 46% соответсвенно.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Не посчитано соотношение категорий пользователей в процентах или в долях от целого, именно это просят в задании. Рекомендую использовать другой тип графика: круговую диаграмму, она лучше показывает соотношение частей целого.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента: </b>Согласна, ниже я добавила новую версию</div>

# %%
#построим сводную таблицу и гистограмму
users.pivot_table(index='subscription_type', values='user_id', aggfunc='count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/1457673932.py in <module>
#       1 #построим сводную таблицу и гистограмму
# ----> 2 users.pivot_table(index='subscription_type', values='user_id', aggfunc='count')
#
# NameError: name 'users' is not defined

# %%
final_sales.plot(y='user_id', autopct='%1.1f%%',
    kind='pie',legend=False, ylabel='',title = "Cоотношение пользователей с подпиской (ultra) и без подписки (free)"
)

# %% [markdown]
# #### Возраст пользователей

# %%
#построим сводную таблицу и гистограмму
users.pivot_table(index='age', values='user_id', aggfunc='count').plot(
    kind='bar',legend=False, ylabel='Количество (чел.)',xlabel='Возраст',title = 'Возраст пользователей',
)
# Out:
# <AxesSubplot:title={'center':'Возраст пользователей'}, xlabel='Возраст', ylabel='Количество (чел.)'>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы рекомендовал подписывать на языке заказчика оси

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента: </b>Исправила в графике выше</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Правильно

# %% [markdown]
# Распределение похоже на нормальное с небольшим смещением влево и пиком в 25 лет. Большинство пользователей находятся в промежутке от 20 до 30 лет, что адекватно отражает реальность. Как правило, поездки на самокатах более свойственны молодым людям и подросткам. Однако, детям до 18 лет может быть проблематично взять самокат в аренду самостоятельно.

# %% [markdown]
# #### Длина поездки (расстояние)

# %%
#Посмотрим на колонку distance
rides['distance'].describe()
# Out:
# count    18068.000000
# mean      3070.659976
# std       1116.831209
# min          0.855683
# 25%       2543.226360
# 50%       3133.609994
# 75%       3776.222735
# max       7211.007745
# Name: distance, dtype: float64

# %%
#Построим гистограмму
dis_graph = rides['distance'].plot(kind='hist',bins=30,title = 'Распределение длины (расстояния) поездкок (м)')

# Задаем подписи осей
dis_graph.set_xlabel('Расстояние (м)')
dis_graph.set_ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# График по данным построен корректно, но не оформлен до конца. Суть в том, что график должен быть наглядным без контекста (т.к. в реальной практике ты будешь показывать презентации или отчет сторонним людям).
#
# Тебе необходимо проследить чтобы всегда был заголовок и подписаны оси. Доработай этот момент пожалуйста.
#
# Данное замечания относится ко всему проекту и перепроверь его самостоятельно. Далее не буду акцентировать на этом внимание

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента: </b>Исправила в графике выше</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
# Учтено

# %% [markdown]
# Средняя длина поездки составляет около 3070 метров. Отсуствуют очень большие выбросы (на графике нету сверхдлинного хвоста) Распределение бимодальное и имеет два выраженных пика: один в районе 600 метров, второй — около 3000 метров. Это может свидетельствовать о наличии двух типов пользовательского поведения — короткие поездки внутри района и более длинные маршруты между удалёнными точками города.

# %% [markdown]
# #### Продолжительность поездок

# %%
#Посмотрим на колонку distance
rides['duration'].describe()
# Out:
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64

# %%
#Построим гистограмму
dur_graph = rides['duration'].plot(kind='hist',bins=30,title = 'Распределение продолжительности поездкок (мин)')

# Задаем подписи осей
dur_graph.set_xlabel('продолжительность')
dur_graph.set_ylabel('количество поездок')
# Out:
# Text(0, 0.5, 'количество поездок')

# %% [markdown]
# Средняя продолжительность поездки составляет около 18 минут. Распределение близко к нормальному, с пиком в районе 15–20 минут. Есть около ста поездок, которые продолжались около одной минуты. Это можеть указывать на аномалии или нестандартные случаи использования сервиса.

# %% [markdown]
# В ходе исследовательского анализа данных были изучены основные характеристики пользователей и их поездок. Пользователи распределены по городам достаточно равномерно, с наибольшим числом в Пятигорске. Возрастная группа 25–35 лет является самой многочисленной. Средняя длина поездки составляет около 3 км, средняя продолжительность — 18 минут. Распределения имеют логичную форму, выявлены отдельные выбросы. Также наблюдаются два пика в длине поездки, что может указывать на разные сценарии использования сервиса. И небольшая аномалия в продолжительности поездок - около 100 поездок, длящихся около минуты.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы графики подкрепить боксплотом

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Учту в будущих проектах</div>

# %% [markdown]
# ### Объединение данных

# %% [markdown]
# #### Объединение данных о пользователях, поездках и подписках в один датафрейм

# %%
#объединим таблицы о пользователях и поездках
total_table = users.merge(rides,on='user_id',how='left',suffixes=('_users','_rides'))
#добавим таблицу с подписками
total_table = total_table.merge(subscriptions,on='subscription_type',how='left',suffixes=('_users','_subscribtions'))
total_table = total_table.drop('index',axis=1)
total_table.head()
# Out:
#    user_id  name  age    city subscription_type     distance   duration  \
# 0        1  Кира   22  Тюмень             ultra  4409.919140  25.599769
# 1        1  Кира   22  Тюмень             ultra  2617.592153  15.816871
# 2        1  Кира   22  Тюмень             ultra   754.159807   6.232113
# 3        1  Кира   22  Тюмень             ultra  2694.783254  18.511000
# 4        1  Кира   22  Тюмень             ultra  4028.687306  26.265803
#
#         date  date_month  minute_price  start_ride_price  subscription_fee
# 0 2021-01-01           1             6                 0               199
# 1 2021-01-18           1             6                 0               199
# 2 2021-04-20           4             6                 0               199
# 3 2021-08-11           8             6                 0               199
# 4 2021-08-28           8             6                 0               199

# %% [markdown]
# Мы используем режим объединения outer, чтобы ничего не упустить. Теперь мы можем проверить нашу общую таблицу на пустые значения.

# %%
total_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
#  5   distance           18068 non-null  float64
#  6   duration           18068 non-null  float64
#  7   date               18068 non-null  datetime64[ns]
#  8   date_month         18068 non-null  int64
#  9   minute_price       18068 non-null  int64
#  10  start_ride_price   18068 non-null  int64
#  11  subscription_fee   18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Пустых значений нет. Таблицы успешно объединены.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично. Проверка размерности датасетов проведена

# %% [markdown]
# #### Создание двух новых датафреймов

# %%
#создадим таблицу c данными о пользователях без подписки
total_table_no_sub = total_table.loc[total_table['subscription_type'] == 'free']
total_table_no_sub.head()
# Out:
#       user_id   name  age  city subscription_type     distance   duration  \
# 6500      700  Айдар   22  Омск              free  2515.690719  14.944286
# 6501      700  Айдар   22  Омск              free   846.932642  16.234663
# 6502      700  Айдар   22  Омск              free  4004.434142  20.016628
# 6503      700  Айдар   22  Омск              free  1205.911290   9.782872
# 6504      700  Айдар   22  Омск              free  3047.379435  17.427673
#
#            date  date_month  minute_price  start_ride_price  subscription_fee
# 6500 2021-01-02           1             8                50                 0
# 6501 2021-02-01           2             8                50                 0
# 6502 2021-02-04           2             8                50                 0
# 6503 2021-02-10           2             8                50                 0
# 6504 2021-02-14           2             8                50                 0

# %%
#создадим таблицу c данными о пользователях с подпиской
total_table_sub = total_table.loc[total_table['subscription_type'] == 'ultra']
total_table_sub.head()
# Out:
#    user_id  name  age    city subscription_type     distance   duration  \
# 0        1  Кира   22  Тюмень             ultra  4409.919140  25.599769
# 1        1  Кира   22  Тюмень             ultra  2617.592153  15.816871
# 2        1  Кира   22  Тюмень             ultra   754.159807   6.232113
# 3        1  Кира   22  Тюмень             ultra  2694.783254  18.511000
# 4        1  Кира   22  Тюмень             ultra  4028.687306  26.265803
#
#         date  date_month  minute_price  start_ride_price  subscription_fee
# 0 2021-01-01           1             6                 0               199
# 1 2021-01-18           1             6                 0               199
# 2 2021-04-20           4             6                 0               199
# 3 2021-08-11           8             6                 0               199
# 4 2021-08-28           8             6                 0               199

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично. Датасеты выведены корректно

# %% [markdown]
# #### Визуализируем расстояние и время поездок для пользователей обеих категорий.

# %%
#построим гистограммы расстояний для пользователей с и без подписки
ax = total_table_no_sub['distance'].plot(kind='hist',bins=30,label='Без подписки',legend=True)
total_table_sub['distance'].plot(kind='hist',bins=30,label='С подпиской',legend=True, ax=ax)

# Добавим подписи осей и заголовок
ax.set_xlabel('Расстояние (м)')
ax.set_ylabel('Количество поездок')
ax.set_title('Расстояние поездки у пользователей с подпиской и без подписки в метрах')
# Out:
# Text(0.5, 1.0, 'Расстояние поездки у пользователей с подпиской и без подписки в метрах')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила подписи к графику</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Спасибо за правки

# %%
#посмотрим на количество поездок с подписками и без
display(total_table_no_sub.shape)
display(total_table_sub.shape)
# Out:
# (11568, 12)
# (6500, 12)

# %%
total_table_no_sub['distance'].describe()
# Out:
# count    11568.000000
# mean      3045.495282
# std       1246.173806
# min          0.855683
# 25%       2366.562689
# 50%       3114.648465
# 75%       3905.697894
# max       7211.007745
# Name: distance, dtype: float64

# %% [markdown]
# Хотя количество пользователей с подпиской и без было примерно одинаково, этого нельзя сказать о количестве поездок. Поездки без подписок почти в два раза превышают количество поездок с подпиской. Пользователи с подпиской совершают, как правило, более длинные поездки — их распределение смещено вправо по сравнению с пользователями без подписки. У пользователей без подписки чаще встречаются короткие маршруты. Это может свидетельствовать о различиях в сценариях использования сервиса: подписка, вероятно, более выгодна для длительных поездок.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# У пользователей без подписки значительно больше коротких поездок - до 1 км и в целом максимальная дальность поездки выше, чем у платных пользователей.

# %%
#построим гистограммы продолжительности поездок для пользователей с подписками и без
az=total_table_no_sub['duration'].plot(kind='hist',bins=30,label='Без подписки',legend=True)
total_table_sub['duration'].plot(kind='hist',bins=30,label='С подпиской',legend=True,ax=az)

# Добавим подписи осей и заголовок
az.set_xlabel('Продолжительность поездки (мин)')
az.set_ylabel('Количество поездок')
az.set_title('Продолжительность поездки у пользователей с подпиской и без подписки в минутах')
# Out:
# Text(0.5, 1.0, 'Продолжительность поездки у пользователей с подпиской и без подписки в минутах')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила подписи к графику</div>

# %% [markdown]
# Пользователи без подписки совершают большее количество поездок, но в среднем их продолжительность немного короче. Пользователи с подпиской совершают менее частые, но более длительные поездки. Распределения похожи по форме и имеют пик в районе 15–20 минут, что говорит о схожих типичных сценариях использования.

# %% [markdown]
# В рамках четвёртого шага данные о пользователях, поездках и подписках были успешно объединены в один датафрейм. На его основе были сформированы отдельные выборки для пользователей с подпиской и без неё. Визуализация позволила выявить различия между этими группами: пользователи с подпиской совершают более продолжительные и дальние поездки, тогда как пользователи без подписки чаще совершают короткие поездки, но в большем количестве.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В целом картина такая же - распределение внутри категорий имеют одинаковый профиль (и одинаковый с профилем распределения до разбивки на категории - строили на ранних этапах), но в каждом из диапазонов бесплатных пользователей чуть больше, но их, как мы помним, и в целом больше.
#
# Краевые значения (минимум и максимум) у бесплатных пользователей смещены влево относительно платных подписчиков - стоимость минуты все-таки больше, значит часть пользователей торопится завершить поездки за меньший срок. Но при этом визуально среднее значение не сильно смещено

# %% [markdown]
# ### Подсчёт выручки

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Нет проверки на пропуски в сводной таблице перед расчетом выручки

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила ниже</div>

# %% [markdown]
# #### Создадим датафрейм с агрегированными данными о поездках

# %%
#перед агрегацией округлим время каждой поездки в большую сторону до минуты
total_table['duration'] = np.ceil(total_table['duration'])

# %%
#найдем суммарное расстояние, количество поездок и суммарное время для каждого пользователя за каждый месяц.
agg_table = total_table.groupby(['user_id', 'date_month']).agg(
    total_distance=('distance', 'sum'),
    trips_count=('distance', 'count'),
    total_duration=('duration', 'sum')
).reset_index()
agg_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11331 entries, 0 to 11330
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         11331 non-null  int64
#  1   date_month      11331 non-null  int64
#  2   total_distance  11331 non-null  float64
#  3   trips_count     11331 non-null  int64
#  4   total_duration  11331 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 442.7 KB

# %% [markdown]
# Пропусков в сводной таблице не найдено, можем приступать к подсчету выручки.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Перед `агрегацией`, нужно округлить время **каждой поездки** в большую сторону до минуты. (поскольку время каждой поездки округляется в большую сторону)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Исправила выше</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично, что используешь именно np.ceil(). Грамотный шаг

# %% [markdown]
# #### Добавим столбец с помесячной выручкой

# %%
#добавим колонку с ценой каждой поездки к общему датафрейму (не включая ежемесячный платеж за подписку)
total_table['price_per_ride'] = total_table['duration'] * total_table['minute_price'] + total_table['start_ride_price']

# %%
#пересоздадим нашу агрегированную таблицу, вкючив новый столбец
agg_table = total_table.groupby(['user_id', 'date_month']).agg(
    total_distance=('distance', 'sum'),
    trips_count=('distance', 'count'),
    total_duration=('duration', 'sum'),
    total_price_per_ride=('price_per_ride', 'sum'),
    sub_price=('subscription_fee','first')
).reset_index()
agg_table
# Out:
#        user_id  date_month  total_distance  trips_count  total_duration  \
# 0            1           1     7027.511294            2            42.0
# 1            1           4      754.159807            1             7.0
# 2            1           8     6723.470560            2            46.0
# 3            1          10     5809.911100            2            32.0
# 4            1          11     7003.499363            3            56.0
# ...        ...         ...             ...          ...             ...
# 11326     1534           6     3409.468534            2            26.0
# 11327     1534           8     7622.453034            2            48.0
# 11328     1534           9     4928.173852            1            23.0
# 11329     1534          11    13350.015305            4            78.0
# 11330     1534          12     2371.711192            1            16.0
#
#        total_price_per_ride  sub_price
# 0                     252.0        199
# ...

# %%
#добавим колонку с финальной выручкой
agg_table['final_revenue'] = agg_table['total_price_per_ride'] + agg_table['sub_price']
agg_table
# Out:
#        user_id  date_month  total_distance  trips_count  total_duration  \
# 0            1           1     7027.511294            2            42.0
# 1            1           4      754.159807            1             7.0
# 2            1           8     6723.470560            2            46.0
# 3            1          10     5809.911100            2            32.0
# 4            1          11     7003.499363            3            56.0
# ...        ...         ...             ...          ...             ...
# 11326     1534           6     3409.468534            2            26.0
# 11327     1534           8     7622.453034            2            48.0
# 11328     1534           9     4928.173852            1            23.0
# 11329     1534          11    13350.015305            4            78.0
# 11330     1534          12     2371.711192            1            16.0
#
#        total_price_per_ride  sub_price  final_revenue
# ...

# %% [markdown]
# На данном этапе был сформирован агрегированный датафрейм, содержащий информацию о количестве поездок, суммарной дистанции и продолжительности поездок каждого пользователя по месяцам. Дополнительно, на основе тарифных условий, рассчитана помесячная выручка, которую принёс каждый пользователь.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Корректная реализация. Молодец)

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# #### Тратят ли пользователи с подпиской больше времени на поездки?

# %% [markdown]
# H₀ (нулевая гипотеза):
# Средняя продолжительность поездки у пользователей с подпиской такое же, как у пользователей без подписки.
#
# H₁ (альтернативная гипотеза):
# Средняя продолжительность поездки у пользователей с подпиской больше, чем у пользователей без подписки.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация нулевой и альтернативной гипотез
# </div>

# %%
#введем переменные с продолжительностями поездок для пользователей с подпиской и без
duration_sub = total_table_sub['duration']
duration_no_sub = total_table_no_sub['duration']
#добавим альфу
alpha = 0.05
# проводим ttest для двух выборок, в качестве альтернативной используем одностороннюю гипотезу "больше"
results = st.ttest_ind(duration_sub, duration_no_sub, alternative ='greater')
print('p-значение:',results.pvalue)
# проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.2804098316645618e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# Мы отвергаем нулевую гипотезу, а значит есть основания говорить, что пользователи с подпиской тратят больше времени на поездки и могут быть «выгоднее» для компании.

# %% [markdown]
# ####  Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает метров?

# %% [markdown]
# H₀ (нулевая гипотеза):
# Среднее расстояние одной поездки у пользователей с подпиской не привышает 3130 метров.
#
# H₁ (альтернативная гипотеза):
# Среднее расстояние одной поездки у пользователей с подпиской более 3130 метров.

# %%
#введем переменную с расстоянием поездки
duration_sub = total_table_sub['distance']
optimal_distance = 3130
#добавим альфу
alpha = 0.05
#проведем ttest, в качестве альтернативной используем одностороннюю гипотезу "больше"
results = st.ttest_1samp(duration_sub, optimal_distance, alternative ='greater')
print('p-значение:',results.pvalue)
# проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.9195368847849785
# Нет оснований отвергнуть нулевую гипотезу

# %% [markdown]
# Нам не удалось отвергнуть нулевую гипотезу, а значит есть основания полагать, что среднее расстояние одной поездки у пользователей с подпиской не привышает 3130 метров.

# %% [markdown]
# #### Будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?

# %% [markdown]
# H₀ (нулевая гипотеза):
# Средняя помесячная выручка от пользователей с подпиской не выше, чем у пользователей без подписки.
#
# H₁ (альтернативная гипотеза):
# Средняя помесячная выручка от пользователей с подпиской выше, чем у пользователей без подписки.

# %%
#введем переменные с помесячной выручкой для пользователей с подпиской и без
revenue_sub = agg_table.loc[agg_table['sub_price'] == 199,'final_revenue']
revenue_no_sub = agg_table.loc[agg_table['sub_price'] == 0,'final_revenue']
#добавим альфу
alpha = 0.05
# проводим ttest для двух выборок, в качестве альтернативной используем одностороннюю гипотезу "меньше"
results = st.ttest_ind(revenue_sub, revenue_no_sub, alternative ='greater')
print('p-значение:',results.pvalue)
# проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.8850394384715216e-31
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Поскольку нам нужно сравнить "выше", поэтому предлагаю изменить Н1 и alternative

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Исправила выше</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Правильно

# %% [markdown]
# Мы опровергли нулевую гиротезу. Это означает, что выручка от подписчиков выше чем у пользователей без подписки. Следовательно пользователи с подпиской более выгодны для сервиса.

# %% [markdown]
# #### Выбор теста

# %% [markdown]
# В нашем примере выборки будут зависимыми, иначе — парными. Парная выборка означает, что некоторая переменная измеряется дважды для одних и тех же объектов.
# Чтобы проверить гипотезу о равенстве среднего генеральной совокупности для зависимых (парных) выборок в Python, применяется метод scipy.stats.ttest_rel().

# %% [markdown]
# В ходе анализа были проверены несколько гипотез, связанных с поведением пользователей с подпиской и без неё:
#
# Мы выявили, что пользователи с подпиской в среднем тратят больше времени на поездку, чем пользователи без подписки. Это может говорить о более активном использовании сервиса и повышенной ценности таких пользователей для компании.
#
# Проверка второй гипотезы  показала, что среднее расстояние поездки у подписчиков не превышает 3130 метров, что соответствует оптимальному значению с точки зрения износа самокатов. Это говорит о том, что подписчики используют самокаты активно, но в пределах допустимой нормы.
#
# При проверке третьей гипотезы мы выяснили, что подписчики, скорее всего, приносят большую выручку, по сравнению с паользователями без подписки, что делает первых более выгодной аудиторией.
#
# Таким образом, все полученные результаты подтверждают потенциальную выгоду от привлечения и удержания пользователей с подпиской.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для решения потребуется тест на равенство средних для зависимых выборок, до и после изменений.>

# %% [markdown]
# ### Вывод

# %% [markdown]
# В рамках проекта был проведён комплексный статистический анализ данных пользователей и поездок сервиса аренды самокатов GoFast. Цель исследования заключалась в том, чтобы понять, насколько пользователи с подпиской выгодны для сервиса по сравнению с пользователями без подписки.
#
# На этапе подготовки данные из трёх источников были успешно объединены, очищены и дополнены новыми признаками, включая номер месяца и индивидуальную выручку по каждой поездке и каждому пользователю.
#
# В ходе исследовательского анализа было выявлено, что распределение пользователей по городам достаточно равномерное, без выраженных аномалий. Похожую картину мы увидели в распределении количества пользователей с подпиской и без - 54% и 46% соответсвенно. Большинство пользователей находятся в промежутке от 20 до 30 лет.
#
# Также мы выяснили, что пользователи с подпиской совершают более продолжительные и частые поездки. Для более точной оценки были рассчитаны агрегированные показатели по каждому пользователю за каждый месяц, включая общее расстояние, количество поездок, суммарную продолжительность и полную выручку с учётом стоимости минуты, старта и ежемесячной абонентской платы.
#
# Далее были сформулированы и проверены статистические гипотезы. Анализ показал, что пользователи с подпиской тратят на поездки статистически значимо больше времени, а среднее расстояние их поездок не превышает оптимальные 3130 метров, что говорит об экономически безопасной нагрузке на технику. При проверке гипотезы о выручке не удалось найти подтверждений тому, что пользователи с подпиской приносят меньше денег — напротив, полученные данные позволяют предположить, что выручка от них выше.
#
# Также в проекте был рассмотрен пример технического эксперимента до и после обновления сервера, и обосновано, что для таких случаев корректно применять парный t-тест.
#
# Таким образом, результаты исследования подтверждают, что пользователи с подпиской являются активными и финансово выгодными клиентами для сервиса GoFast. На основе полученных данных можно рекомендовать компании усилить продвижение подписки Ultra, используя в коммуникации акцент на потенциальную экономию при частом использовании сервиса.
#
# Поскольку пользователи с подпиской совершают поездки дольше, стоит изучить их поведение более глубоко — возможно, они совмещают поездки с другими видами активности (работа, доставка и т.д.), и это открывает перспективы для дополнительных партнёрских интеграций.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Итоговый вывод завершает твое исследование. Представлены основные результаты полученные в ходе анализа, но не увидел каких либо рекомендаций по развитию аренды самокатов в разрезе твоего исследования. Добавь, пожалуйста
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила рекомендации выше</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Тут согласен

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Оформление графиков
#
# 3) Округление
#
#
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метариал по статистике.
#
# * Курс "Вероятность и статистика" | Глеб Михайлов (free): https://www.youtube.com/playlist?list=PLQJ7ptkRY-xbHLLI66KdscKp_FJt0FsIi
#
# * Методы обнаружения выбросов: https://youtu.be/TOK7Kq7x0yc
#
#
# </div>
